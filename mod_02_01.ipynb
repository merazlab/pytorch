# %% [markdown]
# autograd

# %%
import torch

# %%
a = torch.randint(1, 5,(3,))
print(a)
# Out:
# tensor([3, 2, 1])

# %%
print(a.requires_grad)
# Out:
# False

# %%
b = torch.randint(1, 5,(3,), dtype=torch.int16, requires_grad=True)
print(b)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-ef2b572e52ab> in <module>()
# ----> 1 b = torch.randint(1, 5,(3,), dtype=torch.int16, requires_grad=True)
#       2 print(b)
#
# RuntimeError: Only Tensors of floating point dtype can require gradients

# %%
b = torch.randint(1, 5,(3,), dtype=torch.float64, requires_grad=True) #it only support float type data 
print(b)
# Out:
# tensor([2., 3., 4.], dtype=torch.float64, requires_grad=True)

# %%
print(b.grad_fn)
# Out:
# None

# %%
y = b + 2
z = b * 2

# %%
print(y.grad_fn)
print(z.grad_fn)

# %%
a = torch.randn(2, 2)
a = a * 3
print(a.requires_grad)
a.requires_grad_(True)
print(a.requires_grad)
b = (a * a).sum()
print(b.grad_fn)
# Out:
# False
# True
# ...

# %% [markdown]
# Exaple

# %%
x = torch.randint(1, 5,(3,), dtype=torch.float64, requires_grad=True) 
print(x)
# Out:
# tensor([1., 1., 4.], dtype=torch.float64, requires_grad=True)

# %%
y = torch.sum(x**2)

# %%
print(x)
print(y)
print(x.grad)
print(y.grad)
# Out:
# tensor([1., 1., 4.], dtype=torch.float64, requires_grad=True)
# tensor(18., dtype=torch.float64, grad_fn=<SumBackward0>)
# None
# None

# %%
y.backward()

# %%
print(x)
print(y)
print(x.grad)
print(y.grad)
# Out:
# tensor([1., 1., 4.], dtype=torch.float64, requires_grad=True)
# tensor(18., dtype=torch.float64, grad_fn=<SumBackward0>)
# tensor([2., 2., 8.], dtype=torch.float64)
# None

# %%
# Create a variable
x=torch.tensor(torch.arange(0,4), dtype=torch.float64, requires_grad=True)
print(x)

# Differentiate
torch.sum(x**2).backward()
print(x.grad)

# Differentiate again (accumulates gradient)
torch.sum(x**2).backward()
print(x.grad)

# Zero gradient before differentiating
x.grad.data.zero_()
torch.sum(x**2).backward()
print(x.grad)
# Out:
# tensor([0., 1., 2., 3.], dtype=torch.float64, requires_grad=True)
# tensor([0., 2., 4., 6.], dtype=torch.float64)
# tensor([ 0.,  4.,  8., 12.], dtype=torch.float64)
# tensor([0., 2., 4., 6.], dtype=torch.float64)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# detach
#
# detach() method, which returns a tensor with the same data but forgotten the computation history.

# %%
x=torch.tensor(torch.arange(0,4),dtype=torch.float64, requires_grad=True)
y=x**2
z=y**2
print(z.grad_fn)
new_z = z.detach()
print(new_z.grad_fn)
# Out:
# ...
# None
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """Entry point for launching an IPython kernel.

# %%
#You can also stop autograd from tracking history on Tensors. This concept is useful when applying Transfer Learning 
print(x.requires_grad)
print((x+10).requires_grad)

with torch.no_grad():
    print((x+10).requires_grad)
# Out:
# True
# True
# False
